# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
pytorch_results = pd.read_csv("./../data/fastai_results.csv")
pytorch_results
# Out:
#      epoch  train_loss  valid_loss  accuracy  perplexity   time
# 0        0    6.593073    6.366601  0.096367  582.075684  00:23
# 1        1    6.239755    6.033610  0.141133  417.218414  00:23
# 2        2    6.010119    5.796791  0.162060  329.241211  00:23
# 3        3    5.818146    5.624127  0.177879  277.030304  00:23
# 4        4    5.687180    5.501064  0.187146  244.952377  00:23
# ..     ...         ...         ...       ...         ...    ...
# 295    295    3.350130    4.233441  0.306170   68.954086  00:22
# 296    296    3.363213    4.233400  0.306133   68.951256  00:22
# 297    297    3.362036    4.233349  0.306121   68.947777  00:22
# 298    298    3.376943    4.233322  0.306194   68.945900  00:22
# 299    299    3.353091    4.233324  0.306170   68.945999  00:22
#
# [300 rows x 6 columns]

# %%
pytorch_results["perplexity"].to_numpy()
# Out:
# array([582.07568359, 417.21841431, 329.24121094, 277.03030396,
#        244.95237732, 217.30343628, 198.10211182, 180.69891357,
#        168.12867737, 156.55773926, 148.32910156, 140.89852905,
#        134.74919128, 127.83470154, 122.72493744, 117.41902924,
#        113.75179291, 109.66409302, 106.80210114, 104.3181839 ,
#        101.34221649,  98.10773468,  96.29534912,  94.16833496,
#         92.01000214,  90.51072693,  88.88846588,  87.65721893,
#         86.55686188,  85.75036621,  84.40305328,  83.69213867,
#         83.12256622,  82.15435791,  81.21077728,  80.29442596,
#         80.28780365,  79.54013062,  78.91388702,  78.51134491,
#         78.44406128,  78.03014374,  77.05600739,  76.87225342,
#         76.55846405,  76.5925293 ,  76.14901733,  75.8756485 ,
#         75.53495026,  75.35342407,  74.70034027,  75.07260132,
#         74.11131287,  74.22293091,  74.52391052,  74.12774658,
#         74.35442352,  73.11776733,  73.37950897,  73.4335556 ,
# ...

# %%
plot = sns.lineplot(data=pytorch_results, x="epoch", y="perplexity")
plot.set_ylim(50, 100)
# Out:
# /home/gabi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/gabi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# (50.0, 100.0)
